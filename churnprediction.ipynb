# %% [markdown]
# **importing the packages**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(color_codes=True) 
import warnings
warnings.filterwarnings('ignore')

# %%
file_path="D:\\DATA SCIENCE-INTERNSHIPS\\CODEWAY SOLUTIONS INTERNSHIP PROGRAM\\DATA SETS\\customer churn prediction\\Churn_Modelling.csv"
churn_df=pd.read_csv(file_path)
churn_df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
churn_df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
churn_df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
churn_df.size
# Out:
# 140000

# %%
churn_df.shape
# Out:
# (10000, 14)

# %%
churn_df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
churn_df.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
churn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
churn_df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# **we donot have any missing values  in the  dataset**

# %% [markdown]
# **seperation of categorical and numerical columns**

# %%
categorical_columns=[]
numerical_columns=[]
for i,j in churn_df.dtypes.items():
    if j=="O":
        categorical_columns+=[i]
    else:
        numerical_columns+=[i]
print("The categorical columns are :{}".format(categorical_columns))
print("The numerical  columns are : {}".format(numerical_columns))
# Out:
# The categorical columns are :['Surname', 'Geography', 'Gender']
# The numerical  columns are : ['RowNumber', 'CustomerId', 'CreditScore', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary', 'Exited']

# %% [markdown]
# **EDA**

# %% [markdown]
# **working with the categorical columns**

# %%
categorical_columns
# Out:
# ['Surname', 'Geography', 'Gender']

# %% [markdown]
# - **surname which is unique for every person**
# - **so we will work on the Geography and Gender columns**

# %%
for index,i in enumerate(categorical_columns[1:]):
    data=churn_df[i].value_counts()
    my_data=dict(data)
    keys=list(my_data.keys())
    value=list(my_data.values())
    k=pd.DataFrame(zip(keys,value),columns=["keys","values"])
    plt.bar("keys","values",data=k)
    plt.show()

# %% [markdown]
# **working on numerical columns**

# %%
churn_df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
plt.figure(figsize=(15,15))
for index,i in enumerate(numerical_columns[2:]):   
    plt.subplot(3,3,index+1)
    plt.title(i)
    plt.hist(churn_df[i],bins=40)

# %%
plt.figure(figsize=(16,16))
for index,i in enumerate(numerical_columns[2:]):   
    plt.subplot(3,3,index+1)
    plt.title(i)
    plt.boxplot(churn_df[i],vert=False)

# %%
#histplots
num_cols=len(numerical_columns[2:])
num_rows=(num_cols)//3
fig, axs = plt.subplots(nrows=num_rows, ncols=3, figsize=(15, 5*num_rows))
axs = axs.flatten()
for i,j in enumerate(numerical_columns[2:]):
    sns.histplot(data=churn_df, x=j, 
                 hue='Exited', kde=True, ax=axs[i])
    axs[i].set_title(j)
fig.tight_layout()
plt.show()

# %%
churn_df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
sns.kdeplot(data=churn_df, x="Age", hue="Exited", multiple="stack")
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data=churn_df, x="CreditScore", hue="Exited", multiple="stack")
# Out:
# <Axes: xlabel='CreditScore', ylabel='Density'>

# %%
categorical_columns
# Out:
# ['Surname', 'Geography', 'Gender']

# %%
x=churn_df['Geography']
y=churn_df["Exited"]
data=pd.crosstab(x,y)
data.plot(kind="bar")
# Out:
# <Axes: xlabel='Geography'>

# %%
x=churn_df['Gender']
y=churn_df["Exited"]
data=pd.crosstab(x,y)
data.plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %%
x=churn_df['Gender']
z=churn_df['Geography']
y=churn_df["Exited"]
k=[x,z]
data=pd.crosstab(k,y)
data.plot(kind="bar")
# Out:
# <Axes: xlabel='Gender,Geography'>

# %% [markdown]
# **correlation**

# %%
corr_data=churn_df.corr(numeric_only=True)
corr_data
# Out:
#                  RowNumber  CustomerId  CreditScore       Age    Tenure  \
# RowNumber         1.000000    0.004202     0.005840  0.000783 -0.006495
# CustomerId        0.004202    1.000000     0.005308  0.009497 -0.014883
# CreditScore       0.005840    0.005308     1.000000 -0.003965  0.000842
# Age               0.000783    0.009497    -0.003965  1.000000 -0.009997
# Tenure           -0.006495   -0.014883     0.000842 -0.009997  1.000000
# Balance          -0.009067   -0.012419     0.006268  0.028308 -0.012254
# NumOfProducts     0.007246    0.016972     0.012238 -0.030680  0.013444
# HasCrCard         0.000599   -0.014025    -0.005458 -0.011721  0.022583
# IsActiveMember    0.012044    0.001665     0.025651  0.085472 -0.028362
# EstimatedSalary  -0.005988    0.015271    -0.001384 -0.007201  0.007784
# Exited           -0.016571   -0.006248    -0.027094  0.285323 -0.014001
#
#                   Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr_data,annot=True)
# Out:
# <Axes: >

# %%
#converting the categorical columns into the numerical columns

# %%
#we have the three categorical columns we will convert them into  numerical columns

# %%
#surname
#actually surname we donot have any impact in the exited status 
#we can remove that column directly

# %%
#geogrpahy

# %%
churn_df["Geography"]
# Out:
# 0        France
# 1         Spain
# 2        France
# 3        France
# 4         Spain
#          ...
# 9995     France
# 9996     France
# 9997     France
# 9998    Germany
# 9999     France
# Name: Geography, Length: 10000, dtype: object

# %%
churn_df["Geography"].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
churn_df["Geography"].nunique()
# Out:
# 3

# %%
# we can use Label encoder here

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
churn_df["Geography"]=LE.fit_transform(churn_df["Geography"])

# %%
#Gender column

# %%
churn_df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
churn_df["Gender"]=LE.fit_transform(churn_df["Gender"])

# %%
churn_df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619          0       0   42
# 1             2    15647311       Hill          608          2       0   41
# 2             3    15619304       Onio          502          0       0   42
# 3             4    15701354       Boni          699          0       0   39
# 4             5    15737888   Mitchell          850          2       0   43
# ...         ...         ...        ...          ...        ...     ...  ...
# 9995       9996    15606229   Obijiaku          771          0       1   39
# 9996       9997    15569892  Johnstone          516          0       1   35
# 9997       9998    15584532        Liu          709          0       0   36
# 9998       9999    15682355  Sabbatini          772          1       1   42
# 9999      10000    15628319     Walker          792          0       0   28
#
# ...

# %%
**feature selction**
**we can directly remove**
**row number**
**customerid**
**surname**
**as they donot have any impact on the output or target column*

# %%
churn_df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
churn_df=churn_df.drop(["RowNumber","CustomerId",'Surname'],axis=1)
churn_df
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
correlation_values = churn_df.drop('Exited', axis=1).corrwith(churn_df['Exited'])
correlation_values.plot(kind='bar', grid=True, figsize=(10, 6), title="Correlation with Exited status")
plt.show()

# %%
#developing the model

# %%
X=churn_df.drop("Exited",axis=1)
y=churn_df["Exited"]
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=1234,test_size=0.2)

# %%
#quick checks              80% for training the dataset  20% for test the dataset
print(X_train.size)
print(X_test.size)
print(y_train.size)
print(y_test.size)
# Out:
# 80000
# 20000
# 8000
# 2000

# %%
#random forest classifer algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
RFtree=RandomForestClassifier()
RFtree.fit(X_train, y_train)
y_pred_RF=RFtree.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score,roc_auc_score,roc_curve
acc_RF= round(accuracy_score(y_test,y_pred_RF)*100,2)
f1_RF=round(f1_score(y_test,y_pred_RF),2)
precision_RF=round(precision_score(y_test,y_pred_RF),2)
recall_RF=round(recall_score(y_test,y_pred_RF),2)
print("accuray is:",acc_RF)
print("F1 is:",f1_RF)
print("Precision is:",precision_RF)
print("Recall is:",recall_RF)
# Out:
# accuray is: 85.85
# F1 is: 0.57
# Precision is: 0.77
# Recall is: 0.45

# %%
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cmt=confusion_matrix(y_test,y_pred_RF)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()


tn, fp, fn, tp = confusion_matrix(y_test,y_pred_RF).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
# Out:
# True negative: 1532
# False postive: 56
# False negative: 227
# True postive: 185

# %%
y_RF_pred_prob=RFtree.predict_proba(X_test)[:,1]   # Class-1 probabilities
fpr,tpr,threshold=roc_curve(y_test,y_RF_pred_prob) 
plt.plot(fpr,tpr)
plt.show()

# %% [markdown]
# **hyperparameter tuning**

# %%
from sklearn.model_selection import GridSearchCV,cross_val_score
grid_RF=RandomForestClassifier(


    
) 
RF_params=[keys for keys in grid_RF.get_params()]
print(RF_params)
# Out:
# ['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start']

# %%
param_grid = {
    'n_estimators': [100, 200],
    "criterion":['gini','entropy'],
    'max_depth': [5,10,20,30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2'],
    
}

# %%
grid_search = GridSearchCV(grid_RF,  
                           param_grid,
                           scoring='accuracy',
                           cv=5,
                          verbose=True)


grid_search.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200]},
#              scoring='accuracy', verbose=True)

# %%
best_params=grid_search.best_params_
best_score=grid_search.best_score_
print("best params:",best_params)
print("best train accuracy:",best_score)
# Out:
# best params: {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# best train accuracy: 0.863875

# %%
from sklearn.ensemble import RandomForestClassifier
RFtree=RandomForestClassifier(criterion='entropy',max_depth=20,max_features='sqrt',min_samples_leaf=1,min_samples_split=5,n_estimators=100)
RFtree.fit(X_train, y_train)
y_pred_RF=RFtree.predict(X_test)
acc_RF= round(accuracy_score(y_test,y_pred_RF)*100,2)
f1_RF=round(f1_score(y_test,y_pred_RF),2)
precision_RF=round(precision_score(y_test,y_pred_RF),2)
recall_RF=round(recall_score(y_test,y_pred_RF),2)
print("accuray is:",acc_RF)
print("F1 is:",f1_RF)
print("Precision is:",precision_RF)
print("Recall is:",recall_RF)
cmt=confusion_matrix(y_test,y_pred_RF)

disp=ConfusionMatrixDisplay(confusion_matrix=cmt,
                            display_labels = [False, True])
disp.plot()
plt.grid(False)
plt.show()

tn, fp, fn, tp = confusion_matrix(y_test,y_pred_RF).ravel()
print("True negative:",tn)
print("False postive:",fp)
print("False negative:",fn)
print("True postive:",tp)
y_RF_pred_prob=RFtree.predict_proba(X_test)[:,1]   
fpr,tpr,threshold=roc_curve(y_test,y_RF_pred_prob) 
plt.plot(fpr,tpr)
plt.show()
# Out:
# accuray is: 85.9
# F1 is: 0.57
# Precision is: 0.76
# Recall is: 0.46
# True negative: 1530
# False postive: 58
# False negative: 224
# True postive: 188
